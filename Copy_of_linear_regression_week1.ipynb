# %% [markdown]
# <a href="https://colab.research.google.com/github/dishaiit09-beep/IITBDV-Recruitment-Hackathon/blob/main/Copy_of_linear_regression_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 **LISTS AND TUPLES**

# %%
lists = [2,1,13,9,5,6,3,12]
#print(lists[0:len(lists)])
#a=int(input("enter the number to append and then we will sort for you"))
#lists.append(a)
#print("the final list is :",lists[0:len(lists)])
#lists.sort()
#print("the sorted list for u is:",lists[0:len(lists)])
#lists.reverse()
#print(lists[0:len(lists)])
lists.insert(3,33)
print(lists)
# Out:
# [2, 1, 13, 33, 9, 5, 6, 3, 12]

# %%
fruits=[]
for a in range(7) :
  fruits.append(input("enyter fruit name:"))

print(fruits[0:len(fruits)])

# %%
marks = []
for a in range(6):
  marks.append(int(input("marks of student :")))

marks.sort()
  print(marks)

# %%
lists = []
for a in range(4):
 lists.append(input("enter no.:"))

 print(sum(lists))

# %%
a=(7,0,8,0,0,2)
print(a.count(0))
